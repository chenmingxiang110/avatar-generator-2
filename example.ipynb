# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from inference import FaceGen

# %%
fg = FaceGen()

# %%
img, code = fg.generate()
plt.imshow(img[...,::-1])
plt.show()

# %%
cv2.imwrite("results/test.png", img)
# Out:
# True
